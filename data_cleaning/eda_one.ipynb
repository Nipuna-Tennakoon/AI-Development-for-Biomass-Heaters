# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
dataset_dir = "../dataset"
sample_xlsx = "August/01.08.2024-02.08.2024.xlsx"
file_path = os.path.join(dataset_dir, sample_xlsx)
df_1 = pd.read_excel(file_path, sheet_name="Group-1", skiprows=7)
df_2 = pd.read_excel(file_path, sheet_name="Group-2", skiprows=7)
df_3 = pd.read_excel(file_path, sheet_name="Group-3", skiprows=7)
df_4 = pd.read_excel(file_path, sheet_name="Group-4", skiprows=7)

# %%
df_1 = df_1.drop(0,axis=0)
df_2 = df_2.drop(0,axis=0)
df_3 = df_3.drop(0,axis=0)
df_4 = df_4.drop(0,axis=0)

# %%
df_4.head()
# Out:
#              Date Time Economiser Inlet Water Temperature  \
# 1  2024-08-01 06:40:00                          55.700001
# 2  2024-08-01 06:50:00                          56.200001
# 3  2024-08-01 07:00:00                          56.400002
# 4  2024-08-01 07:10:00                          56.400002
# 5  2024-08-01 07:20:00                          56.200001
#
#   Economiser Outlet Water Temperature Economiser Outlet Flue Gas Temperature  \
# 1                           52.299999                              48.200001
# 2                           52.099998                              48.400002
# 3                           52.299999                              48.299999
# 4                           52.599998                                   48.5
# 5                           52.799999                                   48.5
#
#   Hydraulic Power Pack Oil Tank Temperature - Grate  \
# 1                                              30.4
# 2                                         30.299999
# 3                                         30.299999
# 4                                         30.200001
# 5                                              30.1
#
#   T.F. Heater Outlet Flue Gas Temperature Furnace Exit Temperature -1  \
# 1                               55.099998                   53.200001
# 2                               54.700001                   52.900002
# 3                               54.299999                        52.5
# 4                               54.200001                   52.299999
# 5                               54.299999                   52.200001
#
#   Furnace Exit Temperature -2
# 1                   52.400002
# 2                   52.200001
# 3                   51.799999
# 4                        51.5
# 5                   51.299999
