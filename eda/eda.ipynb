# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
check_df_1 = pd.read_csv("../dataset/merged/aug_sep_g1.csv")
check_df_1.head()
# Out:
#              Date Time  T.F.DIFF.Pressure Across Serpentine Coil  \
# 0  2024-08-01 06:40:00                                  0.001374
# 1  2024-08-01 06:50:00                                  0.001447
# 2  2024-08-01 07:00:00                                  0.001447
# 3  2024-08-01 07:10:00                                  0.001447
# 4  2024-08-01 07:20:00                                  0.001519
#
#    T.F Diff. Pressure Transmitter Across MPA  \
# 0                                   0.003436
# 1                                   0.003436
# 2                                   0.003436
# 3                                   0.003436
# 4                                   0.003436
#
#    T.F Heater Outlet Flow Transmitter  Furnace Draft Transmitter  \
# 0                                 0.0                  -1.195385
# 1                                 0.0                  -1.184534
# 2                                 0.0                  -1.164642
# ...

# %%
check_df_1.columns
# Out:
# Index(['Date Time', 'T.F.DIFF.Pressure Across Serpentine Coil',
#        'T.F Diff. Pressure Transmitter Across MPA',
#        'T.F Heater Outlet Flow Transmitter', 'Furnace Draft Transmitter',
#        'PFD Fan Outlet Pressure Transmitter',
#        'SFD Fan Outlet Pressure Transmitter',
#        'T.F Circulation Pump Outlet Header Pressure Transmitter',
#        'Heater Heat Output', 'Total Load Output'],
#       dtype='object')

# %%
check_df_2 = pd.read_csv("../dataset/merged/aug_sep_g2.csv")
check_df_2.columns
# Out:
# Index(['Date Time', 'T.F. Heater Serpentine Coil Inlet Temperature No.1',
#        'T.F. Heater Serpentine Coil Inlet Temperature No.2',
#        'T.F. Heater Serpentine Coil Outlet Temperature',
#        'T.F. Heater Outlet Temperature - 1',
#        'T.F. Heater Outlet Temperature - 2 (Modulation)',
#        'T.F. Heater Outlet Temperature - 3 (Safety)',
#        'T.F. Expansion Tank Temperature - From Client'],
#       dtype='object')

# %%
check_df_3 = pd.read_csv("../dataset/merged/aug_sep_g3.csv")
check_df_3.columns
# Out:
# Index(['Date Time', 'Economiser Inlet Flue Gas Damper Position Feedback',
#        'Economiser Bypass Flue Gas Damper Position Feedback',
#        'Heater Outlet Flue Gas O2 Analyzer',
#        'Primary Air Damper No.1 Position Feedback',
#        'Primary Air Damper No.2 Position Feedback',
#        'Primary Air Damper No.3 Position Feedback',
#        'Secondary Air Damper No.1 Position Feedback',
#        'Secondary Air Damper No.2 Position Feedback'],
#       dtype='object')

# %%
check_df_4 = pd.read_csv("../dataset/merged/aug_sep_g4.csv")
check_df_4.columns
# Out:
# Index(['Date Time', 'Economiser Inlet Water Temperature',
#        'Economiser Outlet Water Temperature',
#        'Economiser Outlet Flue Gas Temperature',
#        'Hydraulic Power Pack Oil Tank Temperature - Grate',
#        'T.F. Heater Outlet Flue Gas Temperature',
#        'Furnace Exit Temperature -1', 'Furnace Exit Temperature -2'],
#       dtype='object')

# %%
final_df = pd.concat([check_df_1[['Date Time','Total Load Output','Heater Heat Output','T.F Heater Outlet Flow Transmitter']], 
                      check_df_2[['T.F. Heater Outlet Temperature - 1','T.F. Heater Outlet Temperature - 2 (Modulation)','T.F. Heater Outlet Temperature - 3 (Safety)','T.F. Heater Serpentine Coil Inlet Temperature No.1','T.F. Heater Serpentine Coil Inlet Temperature No.2','T.F. Heater Serpentine Coil Outlet Temperature']], 
                      check_df_3[['Heater Outlet Flue Gas O2 Analyzer']], 
                      check_df_4[['T.F. Heater Outlet Flue Gas Temperature','Furnace Exit Temperature -1','Furnace Exit Temperature -2']]], axis=1)

# %%
final_df.head(50)
# Out:
#               Date Time  Total Load Output  Heater Heat Output  \
# 0   2024-08-01 06:40:00       17168.501953        0.000000e+00
# 1   2024-08-01 06:50:00       17168.501953        0.000000e+00
# 2   2024-08-01 07:00:00       17168.501953        0.000000e+00
# 3   2024-08-01 07:10:00       17168.501953        0.000000e+00
# 4   2024-08-01 07:20:00       17168.501953        0.000000e+00
# 5   2024-08-01 07:30:00       17168.501953        0.000000e+00
# 6   2024-08-01 07:40:00       17168.501953        0.000000e+00
# 7   2024-08-01 07:50:00       17168.501953        0.000000e+00
# 8   2024-08-01 08:00:00       17168.501953        0.000000e+00
# 9   2024-08-01 08:10:00       17168.501953        0.000000e+00
# 10  2024-08-01 08:20:00       17168.501953        0.000000e+00
# 11  2024-08-01 08:30:00       17168.501953       -6.315240e+05
# 12  2024-08-01 08:40:00       17168.501953       -6.002733e+04
# 13  2024-08-01 08:50:00       17168.501953       -1.057101e+05
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5760 entries, 0 to 5759
# Data columns (total 14 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Date Time                                           5760 non-null   object
#  1   Total Load Output                                   5760 non-null   float64
#  2   Heater Heat Output                                  5760 non-null   float64
#  3   T.F Heater Outlet Flow Transmitter                  5760 non-null   float64
#  4   T.F. Heater Outlet Temperature - 1                  5760 non-null   float64
#  5   T.F. Heater Outlet Temperature - 2 (Modulation)     5760 non-null   float64
#  6   T.F. Heater Outlet Temperature - 3 (Safety)         5760 non-null   float64
#  7   T.F. Heater Serpentine Coil Inlet Temperature No.1  5760 non-null   float64
# ...

# %%
final_df.isnull().sum()
# Out:
# Date Time                                             0
# Total Load Output                                     0
# Heater Heat Output                                    0
# T.F Heater Outlet Flow Transmitter                    0
# T.F. Heater Outlet Temperature - 1                    0
# T.F. Heater Outlet Temperature - 2 (Modulation)       0
# T.F. Heater Outlet Temperature - 3 (Safety)           0
# T.F. Heater Serpentine Coil Inlet Temperature No.1    0
# T.F. Heater Serpentine Coil Inlet Temperature No.2    0
# T.F. Heater Serpentine Coil Outlet Temperature        0
# Heater Outlet Flue Gas O2 Analyzer                    0
# T.F. Heater Outlet Flue Gas Temperature               0
# Furnace Exit Temperature -1                           0
# Furnace Exit Temperature -2                           0
# dtype: int64

# %%
final_df.to_csv('../dataset/final_df.csv', index=False)
