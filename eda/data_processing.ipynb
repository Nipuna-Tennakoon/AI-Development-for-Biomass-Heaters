# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../dataset/final_df_002.csv')
df.head()
# Out:
#              Date Time  Heater Heat Output  \
# 0  2024-08-01 06:40:00           5142770.5
# 1  2024-08-01 06:50:00           5142770.5
# 2  2024-08-01 07:00:00           5142770.5
# 3  2024-08-01 07:10:00           5142770.5
# 4  2024-08-01 07:20:00           5142770.5
#
#    T.F Heater Outlet Flow Transmitter  \
# 0                          489.726562
# 1                          489.726562
# 2                          489.726562
# 3                          489.726562
# 4                          489.726562
#
#    T.F. Heater Serpentine Coil Outlet Temperature  \
# 0                                      223.199997
# 1                                      223.199997
# 2                                      223.199997
# 3                                      223.199997
# 4                                      223.199997
#
#    Heater Outlet Flue Gas O2 Analyzer  \
# 0                            6.488715
# 1                            6.488715
# 2                            6.488715
# ...
