# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../dataset/final_df_002.csv')
df.tail()
# Out:
#                 Date Time  Heater Heat Output  \
# 5755  2024-09-10 05:50:00           5142770.5
# 5756  2024-09-10 06:00:00           5142770.5
# 5757  2024-09-10 06:10:00           5142770.5
# 5758  2024-09-10 06:20:00           5142770.5
# 5759  2024-09-10 06:30:00           5142770.5
#
#       T.F Heater Outlet Flow Transmitter  \
# 5755                          489.726562
# 5756                          489.726562
# 5757                          489.726562
# 5758                          489.726562
# 5759                          489.726562
#
#       T.F. Heater Serpentine Coil Outlet Temperature  \
# 5755                                      223.199997
# 5756                                      223.199997
# 5757                                      223.199997
# 5758                                      223.199997
# 5759                                      223.199997
#
#       Heater Outlet Flue Gas O2 Analyzer  \
# 5755                            6.488715
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5760 entries, 0 to 5759
# Data columns (total 9 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Date Time                                              5760 non-null   object
#  1   Heater Heat Output                                     5760 non-null   float64
#  2   T.F Heater Outlet Flow Transmitter                     5760 non-null   float64
#  3   T.F. Heater Serpentine Coil Outlet Temperature         5760 non-null   float64
#  4   Heater Outlet Flue Gas O2 Analyzer                     5760 non-null   float64
#  5   T.F. Heater Outlet Flue Gas Temperature                5760 non-null   float64
#  6   Average T.F. Heater Outlet Temperature                 5760 non-null   float64
#  7   Average T.F. Heater Serpentine Coil Inlet Temperature  5760 non-null   float64
# ...

# %%
train_size  =  round((len(df)*0.8))
val_size  =  round((len(df)*0.20))

train_size, val_size
# Out:
# (4608, 1152)

# %%
train_df = df[:train_size]
val_df = df[train_size:]

# %%
train_df.tail()
# Out:
#                 Date Time  Heater Heat Output  \
# 4603  2024-09-02 05:50:00           4993324.5
# 4604  2024-09-02 06:00:00           4981369.5
# 4605  2024-09-02 06:10:00           5212754.0
# 4606  2024-09-02 06:20:00           5212486.0
# 4607  2024-09-02 06:30:00           5625693.5
#
#       T.F Heater Outlet Flow Transmitter  \
# 4603                          491.554688
# 4604                          499.851562
# 4605                          499.500000
# 4606                          497.742188
# 4607                          503.414062
#
#       T.F. Heater Serpentine Coil Outlet Temperature  \
# 4603                                      219.300003
# 4604                                      219.000000
# 4605                                      217.899994
# 4606                                      216.800003
# 4607                                      219.500000
#
#       Heater Outlet Flue Gas O2 Analyzer  \
# 4603                            6.482386
# ...

# %%
val_df.head()
# Out:
#                 Date Time  Heater Heat Output  \
# 4608  2024-09-02 06:40:00           5819374.5
# 4609  2024-09-02 06:50:00           5011982.0
# 4610  2024-09-02 07:00:00           4910060.0
# 4611  2024-09-02 07:10:00           5715686.5
# 4612  2024-09-02 07:20:00           6125996.0
#
#       T.F Heater Outlet Flow Transmitter  \
# 4608                          506.132812
# 4609                          501.656250
# 4610                          489.070312
# 4611                          490.523438
# 4612                          495.117188
#
#       T.F. Heater Serpentine Coil Outlet Temperature  \
# 4608                                      218.800003
# 4609                                      216.800003
# 4610                                      217.399994
# 4611                                      218.600006
# 4612                                      222.399994
#
#       Heater Outlet Flue Gas O2 Analyzer  \
# 4608                            6.398293
# ...

# %%
val_df.tail()
# Out:
#                 Date Time  Heater Heat Output  \
# 5755  2024-09-10 05:50:00           5142770.5
# 5756  2024-09-10 06:00:00           5142770.5
# 5757  2024-09-10 06:10:00           5142770.5
# 5758  2024-09-10 06:20:00           5142770.5
# 5759  2024-09-10 06:30:00           5142770.5
#
#       T.F Heater Outlet Flow Transmitter  \
# 5755                          489.726562
# 5756                          489.726562
# 5757                          489.726562
# 5758                          489.726562
# 5759                          489.726562
#
#       T.F. Heater Serpentine Coil Outlet Temperature  \
# 5755                                      223.199997
# 5756                                      223.199997
# 5757                                      223.199997
# 5758                                      223.199997
# 5759                                      223.199997
#
#       Heater Outlet Flue Gas O2 Analyzer  \
# 5755                            6.488715
# ...

# %%
train_df.to_csv('../dataset/train_df.csv', index=False)
val_df.to_csv('../dataset/val_df.csv', index=False)
